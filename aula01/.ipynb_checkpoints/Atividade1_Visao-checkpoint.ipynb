# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 4.2.0

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Crie uma imagem derivada da imagem fornecida que use melhor a faixa dinâmica, ou seja, tenha o valor dos seus pixels distribuídos entre `0` e `255`.
# 3. Plote a imagem pedida

# %%
cte = 255/(58-8)
cte
# Out:
# 5.1

# %%
saida_gray = rintin_gray.copy()

for i in range(rintin_gray.shape[0]):
    for j in range(rintin_gray.shape[1]):
        saida_gray[i][j] = (rintin_gray[i][j]-8)*cte
plt.imshow(saida_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(saida_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(saida_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](cena_canto_sala.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e o creeper azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui. Você vai precisar usar manipulação de canais RGB. Use o [ExemploFor.ipynb](ExemploFor.ipynb) .

# %%
sala = cv2.imread("cena_canto_sala.jpg")

# %%
hist,bins = np.histogram(sala.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(sala.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
plt.imshow(sala, interpolation="none")

# %%
sala_rgb = cv2.cvtColor(sala, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(sala_rgb, interpolation="none")

# %%
sala_r = sala_rgb[:,:,0]
sala_b = sala_rgb[:,:,2]
sala_v = sala_rgb[:,:,1]

# %%
plt.imshow(sala_r, cmap='Greys_r')

# %%
plt.imshow(sala_b, cmap='Greys_r')

# %%
saida_r = sala_r.copy()

hist,bins = np.histogram(sala_r.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(sala_r.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
hist,bins = np.histogram(sala_b.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(sala_b.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
for i in range(sala_r.shape[0]):
    for j in range(sala_r.shape[1]):
        if sala_r[i][j]>210 and sala_b[i][j]<25:
            saida_r[i][j]=255
        else:
            saida_r[i][j]=0

# %%
plt.imshow(saida_r, cmap="Greys_r")

# %% [markdown]
# # Atividade 3
#
#
# Abra a imagem `hall_box_battery_atividade3.png`  e a converta para tons de cinza de `0` a `255`.
#
# Forneça como saída uma uma cópia da imagem  em que cada pixel  recebe o módulo da subtração entre o pixel que vem depois e o que vem antes dele (na horizontal).
#
# Obs.: O conceito de *antes* e *depois* pode ser na horizontal ou na vertical
#
# Apresente a imagem resultado, deve ficar parecida com a imagem `gabarito_atividade_3.png`.
#
# <img src="gabarito_atividade_3.png" width=400>

# %%
box = cv2.imread("hall_box_battery_atividade3.png")

# %%
box.shape
# Out:
# (576, 1024, 3)

# %%
box_gray = cv2.cvtColor(box, cv2.COLOR_BGR2GRAY)

saida_ = box_gray.copy()

# %%
saida_3 = np.zeros((576, 1024), dtype=np.uint8)

# %%
for i in range(box_gray.shape[0]):
    for j in range(box_gray.shape[1]):
        if i == 0 or i == 575:
            pass
        else:
            saida_3[i][j] = int(box_gray[i+1][j]) - int(box_gray[i-1][j])

saida_3 = (saida_3**2)**0.5

# %%
plt.imshow(saida_3, cmap='Greys_r', vmin=0, vmax=255)
